# %% [markdown]
# # test note
#
#
# * jupyterはコンテナ起動すること
# * テストベッド一式起動済みであること

# %%
# !pip install --upgrade pip
# !pip install --force-reinstall ../lib/ait_sdk-0.1.4-py3-none-any.whl
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting pip
#   Downloading pip-20.2.4-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 7.7 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.3
#     Uninstalling pip-20.2.3:
#       Successfully uninstalled pip-20.2.3
# Successfully installed pip-20.2.4
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Processing /workdir/root/lib/ait_sdk-0.1.4-py3-none-any.whl
# Collecting py-cpuinfo
#   Downloading py-cpuinfo-7.0.0.tar.gz (95 kB)
#      |████████████████████████████████| 95 kB 8.8 MB/s eta 0:00:011
# Collecting psutil
#   Downloading psutil-5.7.3.tar.gz (465 kB)
#      |████████████████████████████████| 465 kB 14.5 MB/s eta 0:00:01
# Collecting nbconvert
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
#      |████████████████████████████████| 552 kB 18.1 MB/s eta 0:00:01
# Collecting nbformat
#   Downloading nbformat-5.0.8-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 20.5 MB/s eta 0:00:01
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting numpy
#   Downloading numpy-1.19.2-cp38-cp38-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 20.9 MB/s eta 0:00:01    |█████████████████████▉          | 9.9 MB 20.9 MB/s eta 0:00:01
# Collecting jupyter-core
#   Downloading jupyter_core-4.6.3-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 29.9 MB/s eta 0:00:01
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 43.2 MB/s eta 0:00:01
# Collecting bleach
#   Downloading bleach-3.2.1-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 35.5 MB/s eta 0:00:01
# Collecting defusedxml
#   Downloading defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting jinja2>=2.4
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 32.4 MB/s eta 0:00:01
# Collecting traitlets>=4.2
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 37.9 MB/s ta 0:00:01
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 28.4 MB/s eta 0:00:01
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting pygments>=2.4.1
#   Downloading Pygments-2.7.2-py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 41.2 MB/s eta 0:00:01
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 67.6 MB/s eta 0:00:01
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting scipy>=0.14
#   Downloading scipy-1.5.3-cp38-cp38-manylinux1_x86_64.whl (25.8 MB)
#      |████████████████████████████████| 25.8 MB 23.8 MB/s eta 0:00:01    |█▉                              | 1.5 MB 12.0 MB/s eta 0:00:03     |██████████████████████████████▊ | 24.8 MB 23.8 MB/s eta 0:00:01
# Collecting h5py
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 26.4 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 32.6 MB/s eta 0:00:01
# Collecting jupyter-client>=6.1.5
#   Downloading jupyter_client-6.1.7-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 35.5 MB/s eta 0:00:01
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.4.2-py3-none-any.whl (5.3 kB)
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting six>=1.9.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting packaging
#   Downloading packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp38-cp38-manylinux1_x86_64.whl (32 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
#      |████████████████████████████████| 106 kB 36.9 MB/s eta 0:00:01
# Collecting setuptools
#   Downloading setuptools-50.3.2-py3-none-any.whl (785 kB)
#      |████████████████████████████████| 785 kB 33.8 MB/s eta 0:00:01     |███████████████████▋            | 481 kB 33.8 MB/s eta 0:00:01
# Collecting attrs>=17.4.0
#   Downloading attrs-20.2.0-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 18.4 MB/s eta 0:00:01
# Collecting pyzmq>=13
#   Downloading pyzmq-19.0.2-cp38-cp38-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 32.0 MB/s eta 0:00:01
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 26.4 MB/s eta 0:00:01
# Collecting tornado>=4.1
#   Downloading tornado-6.0.4.tar.gz (496 kB)
#      |████████████████████████████████| 496 kB 17.5 MB/s eta 0:00:01
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 31.8 MB/s eta 0:00:01
# Building wheels for collected packages: py-cpuinfo, psutil, pandocfilters, pyyaml, pyrsistent, tornado
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-7.0.0-py3-none-any.whl size=20070 sha256=e1720110c35721e952d05bf1cd25899eaedc1326cd78b06962695f1647a61f51
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/b4/99/9f/8eb77fdf759c1380719071722f2c37dd0fa1f6aa477c51cb6c
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.3-cp38-cp38-linux_x86_64.whl size=295042 sha256=a7b0ae3e69f3f6f9816927e4dbe134ca44d22fb502520b68a71b0c4476fb13f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/f6/59/c2/38111ef4c354088a156bc95fbeb5396c0cac91a0f62f7158b9
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7991 sha256=67cb499f148f363db1f7215c33bacbda035e358d82faff541bb917f66e5a4993
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/fc/39/52/8d6f3cec1cca4ceb44d658427c35711b19d89dbc4914af657f
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp38-cp38-linux_x86_64.whl size=44619 sha256=39a643f0bf9addb8e9178060508515ab4256ee036566adaa092219b197b4b63c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/13/90/db/290ab3a34f2ef0b5a0f89235dc2d40fea83e77de84ed2dc05c
#   Building wheel for pyrsistent (setup.py) ... done
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp38-cp38-linux_x86_64.whl size=132261 sha256=bcba101b14e677333cef4dec110bd1ee7305a0b5df6dc881a503fed4eaef7443
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/3d/22/08/7042eb6309c650c7b53615d5df5cc61f1ea9680e7edd3a08d2
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.0.4-cp38-cp38-linux_x86_64.whl size=428053 sha256=cc39ee55e647d8a8b384aa5f2f67fb9a4c53b0fe039530738c3332a52163a7b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_ekmf_/wheels/88/79/e5/598ba17e85eccf2626eab62e4ee8452895636cd542650d450d
# Successfully built py-cpuinfo psutil pandocfilters pyyaml pyrsistent tornado
# Installing collected packages: py-cpuinfo, psutil, ipython-genutils, traitlets, jupyter-core, pygments, jupyterlab-pygments, pyrsistent, setuptools, six, attrs, jsonschema, nbformat, pyzmq, python-dateutil, tornado, jupyter-client, nest-asyncio, async-generator, nbclient, pyparsing, packaging, webencodings, bleach, defusedxml, MarkupSafe, jinja2, entrypoints, mistune, testpath, pandocfilters, nbconvert, numpy, scipy, h5py, pyyaml, keras, ait-sdk
#   Attempting uninstall: ipython-genutils
#     Found existing installation: ipython-genutils 0.2.0
#     Uninstalling ipython-genutils-0.2.0:
#       Successfully uninstalled ipython-genutils-0.2.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.4
#     Uninstalling traitlets-5.0.4:
#       Successfully uninstalled traitlets-5.0.4
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.6.3
#     Uninstalling jupyter-core-4.6.3:
#       Successfully uninstalled jupyter-core-4.6.3
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.7.1
#     Uninstalling Pygments-2.7.1:
#       Successfully uninstalled Pygments-2.7.1
#   Attempting uninstall: jupyterlab-pygments
#     Found existing installation: jupyterlab-pygments 0.1.2
#     Uninstalling jupyterlab-pygments-0.1.2:
#       Successfully uninstalled jupyterlab-pygments-0.1.2
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.17.3
#     Uninstalling pyrsistent-0.17.3:
#       Successfully uninstalled pyrsistent-0.17.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 50.3.0
#     Uninstalling setuptools-50.3.0:
#       Successfully uninstalled setuptools-50.3.0
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.2.0
#     Uninstalling attrs-20.2.0:
#       Successfully uninstalled attrs-20.2.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 3.2.0
#     Uninstalling jsonschema-3.2.0:
#       Successfully uninstalled jsonschema-3.2.0
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.7
#     Uninstalling nbformat-5.0.7:
#       Successfully uninstalled nbformat-5.0.7
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 19.0.2
#     Uninstalling pyzmq-19.0.2:
#       Successfully uninstalled pyzmq-19.0.2
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.7
#     Uninstalling jupyter-client-6.1.7:
#       Successfully uninstalled jupyter-client-6.1.7
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.4.1
#     Uninstalling nest-asyncio-1.4.1:
#       Successfully uninstalled nest-asyncio-1.4.1
#   Attempting uninstall: async-generator
#     Found existing installation: async-generator 1.10
#     Uninstalling async-generator-1.10:
#       Successfully uninstalled async-generator-1.10
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.5.0
#     Uninstalling nbclient-0.5.0:
#       Successfully uninstalled nbclient-0.5.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
#   Attempting uninstall: webencodings
#     Found existing installation: webencodings 0.5.1
#     Uninstalling webencodings-0.5.1:
#       Successfully uninstalled webencodings-0.5.1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 3.2.1
#     Uninstalling bleach-3.2.1:
#       Successfully uninstalled bleach-3.2.1
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.6.0
#     Uninstalling defusedxml-0.6.0:
#       Successfully uninstalled defusedxml-0.6.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.3
#     Uninstalling entrypoints-0.3:
#       Successfully uninstalled entrypoints-0.3
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: testpath
#     Found existing installation: testpath 0.4.4
#     Uninstalling testpath-0.4.4:
#       Successfully uninstalled testpath-0.4.4
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.4.2
#     Uninstalling pandocfilters-1.4.2:
#       Successfully uninstalled pandocfilters-1.4.2
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# Successfully installed MarkupSafe-1.1.1 ait-sdk-0.1.4 async-generator-1.10 attrs-20.2.0 bleach-3.2.1 defusedxml-0.6.0 entrypoints-0.3 h5py-2.10.0 ipython-genutils-0.2.0 jinja2-2.11.2 jsonschema-3.2.0 jupyter-client-6.1.7 jupyter-core-4.6.3 jupyterlab-pygments-0.1.2 keras-2.4.3 mistune-0.8.4 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 nest-asyncio-1.4.2 numpy-1.19.2 packaging-20.4 pandocfilters-1.4.3 psutil-5.7.3 py-cpuinfo-7.0.0 pygments-2.7.2 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 pyyaml-5.3.1 pyzmq-19.0.2 scipy-1.5.3 setuptools-50.3.2 six-1.15.0 testpath-0.4.4 tornado-6.0.4 traitlets-5.0.5 webencodings-0.5.1

# %%
from pathlib import Path
import pprint
from ait_sdk.test.hepler import Helper
import json

# %%
# settings cell

# mounted dir
root_dir = Path('/workdir/root/ait')

ait_name='eval_mnist_acc_tf2.3'
ait_version='0.1'

ait_full_name=f'{ait_name}_{ait_version}'
ait_dir = root_dir / ait_full_name

td_name=f'{ait_name}_test'

# (dockerホスト側の)インベントリ登録用アセット格納ルートフォルダ
current_dir = %pwd
with open(f'{current_dir}/config.json', encoding='utf-8') as f:
    json_ = json.load(f)
    root_dir = json_['host_ait_root_dir']
    is_container = json_['is_container']
invenotory_root_dir = f'{root_dir}\\ait\\{ait_full_name}\\local_qai\\inventory'

# entry point address
# コンテナ起動かどうかでポート番号が変わるため、切り替える
if is_container:
    backend_entry_point = 'http://host.docker.internal:8888/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:8888/qai-ip/api/0.0.1'
else:
    backend_entry_point = 'http://host.docker.internal:5000/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:6000/qai-ip/api/0.0.1'

# aitのデプロイフラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_ait = True

# インベントリの登録フラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_inventory = True

# %%
helper = Helper(backend_entry_point=backend_entry_point, 
                ip_entry_point=ip_entry_point,
                ait_dir=ait_dir,
                ait_full_name=ait_full_name)

# %%
# health check

helper.get_bk('/health-check')
helper.get_ip('/health-check')
# Out:
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>

# %%
# create ml-component
res = helper.post_ml_component(name=f'MLComponent_{ait_full_name}', description=f'Description of {ait_full_name}', problem_domain=f'ProbremDomain of {ait_full_name}')
helper.set_ml_component_id(res['MLComponentId'])
# Out:
# <Response [200]>
# {'MLComponentId': 2,
#  'Result': {'Code': 'P22000', 'Message': 'add ml-component success.'}}

# %%
# deploy AIT
if is_init_ait:
    helper.deploy_ait_non_build()
else:
    print('skip deploy AIT')
# Out:
# <Response [400]>
# {'Code': 'T54000', 'Message': 'already exist ait = eval_mnist_acc_tf2.3-0.1'}
# <Response [200]>
# {'Code': 'D00001', 'Message': 'Deploy success'}

# %%
res = helper.get_data_types()
model_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'model'][0]['Id']
dataset_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'dataset'][0]['Id']
res = helper.get_file_systems()
unix_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'UNIX_FILE_SYSTEM'][0]['Id']
windows_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'WINDOWS_FILE'][0]['Id']

# %%
# add inventories

if is_init_inventory:
    inv1_name = helper.post_inventory('trained_model_1', model_data_type_id, unix_file_system_id, 
                                      f'{invenotory_root_dir}\\trained_model\\model_1.h5',
                                      'Tensorflow 2.3で学習したモデル_1', ['h5'])
    inv2_name = helper.post_inventory('test_set_images', dataset_data_type_id, unix_file_system_id, 
                                      f'{invenotory_root_dir}\\test_set_images\\t10k-images-idx3-ubyte.gz',
                                      'テスト画像セット（MNISTフォーマット）', ['gz'])
    inv3_name = helper.post_inventory('test_set_labels', dataset_data_type_id, unix_file_system_id, 
                                      f'{invenotory_root_dir}\\test_set_labels\\t10k-labels-idx1-ubyte.gz',
                                      'テスト画像ラベル（MNISTフォーマット）', ['gz'])
else:
    print('skip add inventories')
# Out:
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}

# %%
# get ait_json and inventory_jsons

res_json = helper.get_bk('/QualityMeasurements/RelationalOperators', is_print_json=False).json()
eq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '=='][0])
nq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '!='][0])
gt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>'][0])
ge_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>='][0])
lt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<'][0])
le_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<='][0])

res_json = helper.get_bk('/testRunners', is_print_json=False).json()
ait_json = [j for j in res_json['TestRunners'] if j['Name'] == ait_name][-1]

inv_1_json = helper.get_inventory(inv1_name)
inv_2_json = helper.get_inventory(inv2_name)
inv_3_json = helper.get_inventory(inv3_name)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# add teast_descriptions

helper.post_td(td_name, 5,
               quality_measurements=[
                {"Id":ait_json['Report']['Measures'][0]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][1]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][2]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][3]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][4]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][5]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][6]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][7]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][8]['Id'], "Value":"0.95", "RelationalOperatorId":gt_id, "Enable":True}
               ],
               target_inventories=[
                {"Id":1, "InventoryId": inv_1_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][0]['Id']},
                {"Id":2, "InventoryId": inv_2_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][1]['Id']},
                {"Id":2, "InventoryId": inv_3_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][2]['Id']}
               ],
               test_runner={
                "Id":ait_json['Id'],
                "Params":[
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][0]['Id'], "Value":"10"},
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][1]['Id'], "Value":"28"},
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][2]['Id'], "Value":"macro"},
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][3]['Id'], "Value":"raise"}
                ]
               })
# Out:
# <Response [200]>
# {'Result': {'Code': 'T22000', 'Message': 'append test description success.'}}

# %%
# get test_description_jsons
td_1_json = helper.get_td(td_name)
# Out:
# <Response [200]>

# %%
# run test_descriptions
helper.post_run_and_wait(td_1_json['Id'])
# Out:
# <Response [200]>
# {'Job': {'Id': '1', 'StartDateTime': '2020-10-26 14:02:39.769862+09:00'},
#  'Result': {'Code': 'R12000', 'Message': 'job launch success.'}}
# [{'Id': 1,
#   'Result': 'OK',
#   'ResultDetail': 'Accuracy : OK.\n'
#                   'Precision : OK.\n'
#                   'Recall : OK.\n'
#                   'F−measure : OK.\n'
#                   'AccuracyByClass : OK.\n'
#                   'PrecisionByClass : OK.\n'
#                   'RecallByClass : OK.\n'
#                   'F−measureByClass : OK.\n'
#                   'AUC : OK.\n',
#   'Status': 'DONE',
#   'TestDescriptionID': 2}]

# %%
res_json = helper.get_td_detail(td_1_json['Id'])
pprint.pprint(res_json)
# Out:
# <Response [200]>
# {'Result': {'Code': 'T32000', 'Message': 'get detail success.'},
#  'TestDescriptionDetail': {'Id': 2,
#                            'Name': 'eval_mnist_acc_tf2.3_test',
#                            'Opinion': '',
#                            'QualityDimension': {'Id': 5, 'Name': '機械学習モデルの正確性'},
#                            'QualityMeasurements': [{'Description': '(TP+TN) / '
#                                                                    '(TP+FP+FN+TN)',
#                                                     'Enable': True,
#                                                     'Id': 2,
#                                                     'Name': 'Accuracy',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'TP / '
#                                                                    '(TP+FP)',
#                                                     'Enable': True,
#                                                     'Id': 3,
#                                                     'Name': 'Precision',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'TP / '
#                                                                    '(TP+FN)',
#                                                     'Enable': True,
#                                                     'Id': 4,
#                                                     'Name': 'Recall',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '0.95'},
#                                                    {'Description': '(2Recall∗Precision) '
#                                                                    '/ '
#                                                                    '(Recall+Precision)',
#                                                     'Enable': True,
#                                                     'Id': 5,
#                                                     'Name': 'F−measure',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'Area under '
#                                                                    'the ROC '
#                                                                    'curve',
#                                                     'Enable': True,
#                                                     'Id': 6,
#                                                     'Name': 'AUC',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'Accuracy '
#                                                                    'for each '
#                                                                    'class.',
#                                                     'Enable': True,
#                                                     'Id': 7,
#                                                     'Name': 'AccuracyByClass',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'sequence',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'Precision '
#                                                                    'for each '
#                                                                    'class.',
#                                                     'Enable': True,
#                                                     'Id': 8,
#                                                     'Name': 'PrecisionByClass',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'sequence',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'Recall for '
#                                                                    'each '
#                                                                    'class.',
#                                                     'Enable': True,
#                                                     'Id': 9,
#                                                     'Name': 'RecallByClass',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'sequence',
#                                                     'Value': '0.95'},
#                                                    {'Description': 'F−measure '
#                                                                    'for each '
#                                                                    'class.',
#                                                     'Enable': True,
#                                                     'Id': 10,
#                                                     'Name': 'F−measureByClass',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'sequence',
#                                                     'Value': '0.95'}],
#                            'Star': False,
#                            'TargetInventories': [{'DataType': {'Id': 2,
#                                                                'Name': 'model'},
#                                                   'Description': 'Tensorflow '
#                                                                  '2.3で学習したモデル_1',
#                                                   'Id': 2,
#                                                   'Name': 'eval_mnist_acc_tf2.3_0.1_trained_model_1',
#                                                   'TemplateInventoryId': 2},
#                                                  {'DataType': {'Id': 1,
#                                                                'Name': 'dataset'},
#                                                   'Description': 'テスト画像セット（MNISTフォーマット）',
#                                                   'Id': 3,
#                                                   'Name': 'eval_mnist_acc_tf2.3_0.1_test_set_images',
#                                                   'TemplateInventoryId': 3},
#                                                  {'DataType': {'Id': 1,
#                                                                'Name': 'dataset'},
#                                                   'Description': 'テスト画像ラベル（MNISTフォーマット）',
#                                                   'Id': 4,
#                                                   'Name': 'eval_mnist_acc_tf2.3_0.1_test_set_labels',
#                                                   'TemplateInventoryId': 4}],
#                            'TestDescriptionResult': {'Detail': 'Accuracy : '
#                                                                'OK.\n'
#                                                                'Precision : '
#                                                                'OK.\n'
#                                                                'Recall : OK.\n'
#                                                                'F−measure : '
#                                                                'OK.\n'
#                                                                'AccuracyByClass '
#                                                                ': OK.\n'
#                                                                'PrecisionByClass '
#                                                                ': OK.\n'
#                                                                'RecallByClass '
#                                                                ': OK.\n'
#                                                                'F−measureByClass '
#                                                                ': OK.\n'
#                                                                'AUC : OK.\n',
#                                                      'Downloads': [{'Description': '混同行列',
#                                                                     'DownloadURL': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/14',
#                                                                     'Id': 1,
#                                                                     'Name': 'ConfusionMatrixCSV'},
#                                                                    {'Description': 'ID,正解ラベル,推論結果確率(ラベル毎)',
#                                                                     'DownloadURL': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/15',
#                                                                     'Id': 2,
#                                                                     'Name': 'PredictionResult'},
#                                                                    {'Description': 'AIT実行ログ',
#                                                                     'DownloadURL': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/16',
#                                                                     'Id': 3,
#                                                                     'Name': 'Log'}],
#                                                      'Graphs': [{'Description': '混同行列(ヒートマップ)',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/2',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 1,
#                                                                  'Name': 'ConfusionMatrixHeatmap',
#                                                                  'ReportIndex': 1,
#                                                                  'ReportName': 'ConfusionMatrixHeatmap',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'ROC曲線',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/3',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 2,
#                                                                  'Name': 'ROC-curve',
#                                                                  'ReportIndex': 2,
#                                                                  'ReportName': 'ROC-curve',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/4',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 3,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 3,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/5',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 4,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 4,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/6',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 5,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 5,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/7',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 6,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 6,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/8',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 7,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 7,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/9',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 8,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 8,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/10',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 9,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 9,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/11',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 10,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 10,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/12',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 11,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 11,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': '推論NGとなった画像の一覧を、正解ラベルの枚数分だけ出力する',
#                                                                  'Graph': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/13',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 12,
#                                                                  'Name': 'NGPredictImages',
#                                                                  'ReportIndex': 12,
#                                                                  'ReportName': 'NGPredictImages',
#                                                                  'ReportRequired': True}],
#                                                      'LogFile': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/17',
#                                                      'Summary': 'OK'},
#                            'TestRunner': {'Author': 'AIST',
#                                           'Description': 'Only Sequential API '
#                                                          'Model\n'
#                                                          '\n'
#                                                          '<QualityMeasurement>\n'
#                                                          'Accuracy=TP+TNTP+FP+FN+TN\n'
#                                                          'Precision=TPTP+FP\n'
#                                                          'Recall=TPTP+FN\n'
#                                                          'F−measure=2Recall∗PrecisionRecall+Precision\n'
#                                                          'AUC\n'
#                                                          '\n'
#                                                          '<Resources>\n'
#                                                          'ROC曲線\n'
#                                                          '混同行列\n'
#                                                          'NG予測画像',
#                                           'Email': '',
#                                           'Id': 2,
#                                           'LandingPage': '',
#                                           'Name': 'eval_mnist_acc_tf2.3',
#                                           'Params': [{'Id': 2,
#                                                       'Name': 'class_count',
#                                                       'TestRunnerParamTemplateId': 2,
#                                                       'Value': '10'},
#                                                      {'Id': 3,
#                                                       'Name': 'image_px_size',
#                                                       'TestRunnerParamTemplateId': 3,
#                                                       'Value': '28'},
#                                                      {'Id': 4,
#                                                       'Name': 'auc_average',
#                                                       'TestRunnerParamTemplateId': 4,
#                                                       'Value': 'macro'},
#                                                      {'Id': 5,
#                                                       'Name': 'auc_multi_class',
#                                                       'TestRunnerParamTemplateId': 5,
#                                                       'Value': 'raise'}],
#                                           'Quality': 'https://airc.aist.go.jp/aiqm/quality/internal/機械学習モデルの正確性',
#                                           'Version': '0.1'}}}

# %%
# generate report
res = helper.post_report(td_1_json['Id'])
pprint.pprint(res)
# Out:
# <Response [200]>
# {'OutParams': {'ReportUrl': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/18'},
#  'Result': {'Code': 'D12000', 'Message': 'command invoke success.'}}
# {'OutParams': {'ReportUrl': 'http://127.0.0.1:8888/qai-testbed/api/0.0.1/download/18'},
#  'Result': {'Code': 'D12000', 'Message': 'command invoke success.'}}
