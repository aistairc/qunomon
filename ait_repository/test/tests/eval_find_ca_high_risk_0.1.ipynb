# %% [markdown]
# # test note
#
#
# * jupyterはコンテナ起動すること
# * テストベッド一式起動済みであること

# %%
# !pip install --upgrade pip
# !pip install --force-reinstall ../lib/ait_sdk-0.1.4-py3-none-any.whl
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (20.2.4)
# Processing /workdir/root/lib/ait_sdk-0.1.4-py3-none-any.whl
# Collecting psutil<=5.7.3
#   Downloading psutil-5.7.3.tar.gz (465 kB)
#      |████████████████████████████████| 465 kB 3.3 MB/s eta 0:00:01
# Collecting keras<=2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting nbformat<=5.0.8
#   Using cached nbformat-5.0.8-py3-none-any.whl (172 kB)
# Collecting py-cpuinfo<=7.0.0
#   Downloading py-cpuinfo-7.0.0.tar.gz (95 kB)
#      |████████████████████████████████| 95 kB 6.0 MB/s  eta 0:00:01
# Collecting numpy<=1.19.3
#   Downloading numpy-1.19.3-cp36-cp36m-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 7.6 MB/s eta 0:00:01    |██████████████                  | 6.5 MB 6.3 MB/s eta 0:00:02
# Collecting nbconvert<=6.0.7
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting scipy>=0.14
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 12.0 MB/s eta 0:00:01    |███▊                            | 3.0 MB 10.8 MB/s eta 0:00:03
# Collecting h5py
#   Downloading h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 20.8 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 10.8 MB/s eta 0:00:01
# Collecting traitlets>=4.1
#   Using cached traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
# Collecting jupyter-core
#   Using cached jupyter_core-4.6.3-py2.py3-none-any.whl (83 kB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting entrypoints>=0.2.2
#   Using cached entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting bleach
#   Using cached bleach-3.2.1-py2.py3-none-any.whl (145 kB)
# Collecting jinja2>=2.4
#   Using cached Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting testpath
#   Using cached testpath-0.4.4-py2.py3-none-any.whl (163 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Using cached nbclient-0.5.1-py3-none-any.whl (65 kB)
# Collecting pygments>=2.4.1
#   Downloading Pygments-2.7.2-py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 3.5 MB/s eta 0:00:01
# Collecting cached-property; python_version < "3.8"
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting six
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting decorator
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 1.2 MB/s eta 0:00:011
# Processing /root/.cache/pip/wheels/34/13/19/294da8e11bce7e563afee51251b9fa878185e14f4b5caf00cb/pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl
# Collecting setuptools
#   Using cached setuptools-50.3.2-py3-none-any.whl (785 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting packaging
#   Using cached packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting MarkupSafe>=0.23
#   Using cached MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting async-generator
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.4.2-py3-none-any.whl (5.3 kB)
# Collecting jupyter-client>=6.1.5
#   Using cached jupyter_client-6.1.7-py3-none-any.whl (108 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting pyparsing>=2.0.2
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting python-dateutil>=2.1
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting tornado>=4.1
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
#      |████████████████████████████████| 427 kB 13.0 MB/s eta 0:00:01
# Collecting pyzmq>=13
#   Using cached pyzmq-19.0.2-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Building wheels for collected packages: psutil, py-cpuinfo, pyyaml, pandocfilters
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.3-cp36-cp36m-linux_x86_64.whl size=288556 sha256=c7cd13773134714f69bb1d3860c29ca7ad1d0da909322d9d57f978016287ea4d
#   Stored in directory: /root/.cache/pip/wheels/fa/ad/67/90bbaacdcfe970960dd5158397f23a6579b51d853720d7856d
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-7.0.0-py3-none-any.whl size=20299 sha256=1071f952ba16cd3e43931339c1c6cff3e36881fc34b1071b839c2ccafbe62868
#   Stored in directory: /root/.cache/pip/wheels/46/6d/cc/73a126dc2e09fe56fcec0a7386d255762611fbed1c86d3bbcc
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=45919 sha256=ca7725addfc4aa8dac2fec4b2385c316c82126ddef6deb2d698f126d4744adf4
#   Stored in directory: /root/.cache/pip/wheels/e5/9d/ad/2ee53cf262cba1ffd8afe1487eef788ea3f260b7e6232a80fc
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=10627 sha256=6c0c07f9da8f6578f9e6c96714a914641ec85f38755331a7b685797ab289a6f5
#   Stored in directory: /root/.cache/pip/wheels/12/12/89/fe63ac4d6ee6440daab4db77b78c63f7f192b700f844b6639f
# Successfully built psutil py-cpuinfo pyyaml pandocfilters
# Installing collected packages: psutil, numpy, scipy, cached-property, h5py, pyyaml, keras, ipython-genutils, six, decorator, traitlets, jupyter-core, zipp, importlib-metadata, attrs, pyrsistent, setuptools, jsonschema, nbformat, py-cpuinfo, pygments, jupyterlab-pygments, entrypoints, webencodings, pyparsing, packaging, bleach, MarkupSafe, jinja2, defusedxml, mistune, testpath, pandocfilters, async-generator, nest-asyncio, python-dateutil, tornado, pyzmq, jupyter-client, nbclient, nbconvert, ait-sdk
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: ipython-genutils
#     Found existing installation: ipython-genutils 0.2.0
#     Uninstalling ipython-genutils-0.2.0:
#       Successfully uninstalled ipython-genutils-0.2.0
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 4.3.3
#     Uninstalling traitlets-4.3.3:
#       Successfully uninstalled traitlets-4.3.3
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.6.3
#     Uninstalling jupyter-core-4.6.3:
#       Successfully uninstalled jupyter-core-4.6.3
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.1.0
#     Uninstalling zipp-3.1.0:
#       Successfully uninstalled zipp-3.1.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 1.7.0
#     Uninstalling importlib-metadata-1.7.0:
#       Successfully uninstalled importlib-metadata-1.7.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.2.0
#     Uninstalling attrs-20.2.0:
#       Successfully uninstalled attrs-20.2.0
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.17.3
#     Uninstalling pyrsistent-0.17.3:
#       Successfully uninstalled pyrsistent-0.17.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 50.3.2
#     Uninstalling setuptools-50.3.2:
#       Successfully uninstalled setuptools-50.3.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 3.2.0
#     Uninstalling jsonschema-3.2.0:
#       Successfully uninstalled jsonschema-3.2.0
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.8
#     Uninstalling nbformat-5.0.8:
#       Successfully uninstalled nbformat-5.0.8
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.7.1
#     Uninstalling Pygments-2.7.1:
#       Successfully uninstalled Pygments-2.7.1
#   Attempting uninstall: jupyterlab-pygments
#     Found existing installation: jupyterlab-pygments 0.1.2
#     Uninstalling jupyterlab-pygments-0.1.2:
#       Successfully uninstalled jupyterlab-pygments-0.1.2
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.3
#     Uninstalling entrypoints-0.3:
#       Successfully uninstalled entrypoints-0.3
#   Attempting uninstall: webencodings
#     Found existing installation: webencodings 0.5.1
#     Uninstalling webencodings-0.5.1:
#       Successfully uninstalled webencodings-0.5.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
#   Attempting uninstall: bleach
#     Found existing installation: bleach 3.2.1
#     Uninstalling bleach-3.2.1:
#       Successfully uninstalled bleach-3.2.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.6.0
#     Uninstalling defusedxml-0.6.0:
#       Successfully uninstalled defusedxml-0.6.0
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: testpath
#     Found existing installation: testpath 0.4.4
#     Uninstalling testpath-0.4.4:
#       Successfully uninstalled testpath-0.4.4
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.4.2
#     Uninstalling pandocfilters-1.4.2:
#       Successfully uninstalled pandocfilters-1.4.2
#   Attempting uninstall: async-generator
#     Found existing installation: async-generator 1.10
#     Uninstalling async-generator-1.10:
#       Successfully uninstalled async-generator-1.10
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.4.1
#     Uninstalling nest-asyncio-1.4.1:
#       Successfully uninstalled nest-asyncio-1.4.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 19.0.2
#     Uninstalling pyzmq-19.0.2:
#       Successfully uninstalled pyzmq-19.0.2
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.7
#     Uninstalling jupyter-client-6.1.7:
#       Successfully uninstalled jupyter-client-6.1.7
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.5.1
#     Uninstalling nbclient-0.5.1:
#       Successfully uninstalled nbclient-0.5.1
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# tensorflow 2.3.0 requires h5py<2.11.0,>=2.10.0, but you'll have h5py 3.1.0 which is incompatible.
# tensorflow 2.3.0 requires numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.3 which is incompatible.
# tensorflow 2.3.0 requires scipy==1.4.1, but you'll have scipy 1.5.4 which is incompatible.
# Successfully installed MarkupSafe-1.1.1 ait-sdk-0.1.4 async-generator-1.10 attrs-20.3.0 bleach-3.2.1 cached-property-1.5.2 decorator-4.4.2 defusedxml-0.6.0 entrypoints-0.3 h5py-3.1.0 importlib-metadata-2.0.0 ipython-genutils-0.2.0 jinja2-2.11.2 jsonschema-3.2.0 jupyter-client-6.1.7 jupyter-core-4.6.3 jupyterlab-pygments-0.1.2 keras-2.4.3 mistune-0.8.4 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 nest-asyncio-1.4.2 numpy-1.19.3 packaging-20.4 pandocfilters-1.4.3 psutil-5.7.3 py-cpuinfo-7.0.0 pygments-2.7.2 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 pyyaml-5.3.1 pyzmq-19.0.2 scipy-1.5.4 setuptools-50.3.2 six-1.15.0 testpath-0.4.4 tornado-6.1 traitlets-4.3.3 webencodings-0.5.1 zipp-3.4.0

# %%
from pathlib import Path
import pprint
from ait_sdk.test.hepler import Helper
import json

# %%
# settings cell

# mounted dir
root_dir = Path('/workdir/root/ait')

ait_name='eval_find_ca_high_risk'
ait_version='0.1'

ait_full_name=f'{ait_name}_{ait_version}'
ait_dir = root_dir / ait_full_name

td_name=f'{ait_name}_test'

# (dockerホスト側の)インベントリ登録用アセット格納ルートフォルダ
current_dir = %pwd
with open(f'{current_dir}/config.json', encoding='utf-8') as f:
    json_ = json.load(f)
    root_dir = json_['host_ait_root_dir']
    is_container = json_['is_container']
invenotory_root_dir = f'{root_dir}\\ait\\{ait_full_name}\\local_qai\\inventory'

# entry point address
# コンテナ起動かどうかでポート番号が変わるため、切り替える
if is_container:
    backend_entry_point = 'http://host.docker.internal:8888/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:8888/qai-ip/api/0.0.1'
else:
    backend_entry_point = 'http://host.docker.internal:5000/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:6000/qai-ip/api/0.0.1'

# aitのデプロイフラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_ait = True

# インベントリの登録フラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_inventory = True

# %%
helper = Helper(backend_entry_point=backend_entry_point, 
                ip_entry_point=ip_entry_point,
                ait_dir=ait_dir,
                ait_full_name=ait_full_name)

# %%
# health check

helper.get_bk('/health-check')
helper.get_ip('/health-check')
# Out:
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>

# %%
# create ml-component
res = helper.post_ml_component(name=f'MLComponent_{ait_full_name}', description=f'Description of {ait_full_name}', problem_domain=f'ProbremDomain of {ait_full_name}')
helper.set_ml_component_id(res['MLComponentId'])
# Out:
# <Response [200]>
# {'MLComponentId': 4,
#  'Result': {'Code': 'P22000', 'Message': 'add ml-component success.'}}

# %%
# deploy AIT
if is_init_ait:
    helper.deploy_ait_non_build()
else:
    print('skip deploy AIT')
# Out:
# <Response [200]>
# {'Code': 'M00001', 'Message': 'Add AIT manifest success'}
# <Response [200]>
# {'Code': 'D00001', 'Message': 'Deploy success'}

# %%
res = helper.get_data_types()
model_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'model'][0]['Id']
dataset_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'dataset'][0]['Id']
attribute_set_type_id = [d for d in res['DataTypes'] if d['Name'] == 'attribute set'][0]['Id']
res = helper.get_file_systems()
unix_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'UNIX_FILE_SYSTEM'][0]['Id']
windows_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'WINDOWS_FILE'][0]['Id']

# %%
# add inventories

if is_init_inventory:
    inv1_name = helper.post_inventory('Data', dataset_data_type_id, windows_file_system_id, 
                                      f'{invenotory_root_dir}\\data\\BDD_labels_2036.csv',
                                      'data set', ['csv'])
    inv2_name = helper.post_inventory('High_risk_CA_combinations', attribute_set_type_id, windows_file_system_id, 
                                      f'{invenotory_root_dir}\\HighRisk_CA_combinations\\HighRisk_CA_combination_cases.csv',
                                      'attribute set', ['csv'])
else:
    print('skip add inventories')
# Out:
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}

# %%
# get ait_json and inventory_jsons

res_json = helper.get_bk('/QualityMeasurements/RelationalOperators', is_print_json=False).json()
eq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '=='][0])
nq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '!='][0])
gt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>'][0])
ge_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>='][0])
lt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<'][0])
le_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<='][0])

res_json = helper.get_bk('/testRunners', is_print_json=False).json()
ait_json = [j for j in res_json['TestRunners'] if j['Name'] == ait_name][-1]

inv_1_json = helper.get_inventory(inv1_name)
inv_2_json = helper.get_inventory(inv2_name)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# add teast_descriptions

helper.post_td(td_name, ait_json['QualityDimensionId'],
               quality_measurements=[
                {"Id":ait_json['Report']['Measures'][0]['Id'], "Value":"10", "RelationalOperatorId":gt_id, "Enable":True},
                {"Id":ait_json['Report']['Measures'][1]['Id'], "Value":"100", "RelationalOperatorId":gt_id, "Enable":True}
               ],
               target_inventories=[
                {"Id":1, "InventoryId": inv_1_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][0]['Id']},
                {"Id":2, "InventoryId": inv_2_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][1]['Id']}
               ],
               test_runner={
                "Id":ait_json['Id'],
                "Params":[
                ]
               })
# Out:
# <Response [200]>
# {'Result': {'Code': 'T22000', 'Message': 'append test description success.'}}

# %%
# get test_description_jsons
td_1_json = helper.get_td(td_name)
# Out:
# <Response [200]>

# %%
# run test_descriptions
helper.post_run_and_wait(td_1_json['Id'])
# Out:
# <Response [200]>
# {'Job': {'Id': '1', 'StartDateTime': '2020-11-11 13:41:17.890425+09:00'},
#  'Result': {'Code': 'R12000', 'Message': 'job launch success.'}}
# [{'Id': 1,
#   'Result': 'OK',
#   'ResultDetail': 'SingleCount : OK.\nCombinedCount : OK.\n',
#   'Status': 'DONE',
#   'TestDescriptionID': 4}]

# %%
res_json = helper.get_td_detail(td_1_json['Id'])
pprint.pprint(res_json)
# Out:
# <Response [200]>
# {'Result': {'Code': 'T32000', 'Message': 'get detail success.'},
#  'TestDescriptionDetail': {'Id': 4,
#                            'Name': 'eval_find_ca_high_risk_test',
#                            'Opinion': '',
#                            'QualityDimension': {'Id': 3, 'Name': 'データセットの被覆性'},
#                            'QualityMeasurements': [{'Description': 'Number of '
#                                                                    'high risk '
#                                                                    'cases in '
#                                                                    'simple '
#                                                                    'combinations',
#                                                     'Enable': True,
#                                                     'Id': 4,
#                                                     'Name': 'SingleCount',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '10'},
#                                                    {'Description': 'Number of '
#                                                                    'high risk '
#                                                                    'cases in '
#                                                                    'combine '
#                                                                    'combinations',
#                                                     'Enable': True,
#                                                     'Id': 5,
#                                                     'Name': 'CombinedCount',
#                                                     'RelationalOperatorId': 3,
#                                                     'Structure': 'single',
#                                                     'Value': '100'}],
#                            'Star': False,
#                            'TargetInventories': [{'DataType': {'Id': 1,
#                                                                'Name': 'dataset'},
#                                                   'Description': 'data set',
#                                                   'Id': 7,
#                                                   'Name': 'eval_find_ca_high_risk_0.1_Data',
#                                                   'TemplateInventoryId': 7},
#                                                  {'DataType': {'Id': 3,
#                                                                'Name': 'attribute '
#                                                                        'set'},
#                                                   'Description': 'attribute '
#                                                                  'set',
#                                                   'Id': 8,
#                                                   'Name': 'eval_find_ca_high_risk_0.1_High_risk_CA_combinations',
#                                                   'TemplateInventoryId': 8}],
#                            'TestDescriptionResult': {'Detail': 'SingleCount : '
#                                                                'OK.\n'
#                                                                'CombinedCount '
#                                                                ': OK.\n',
#                                                      'Downloads': [{'Description': 'AITLog',
#                                                                     'DownloadURL': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/195',
#                                                                     'Id': 1,
#                                                                     'Name': 'Log'}],
#                                                      'Graphs': [{'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'each '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/2',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 1,
#                                                                  'Name': 'CountResult',
#                                                                  'ReportIndex': 1,
#                                                                  'ReportName': 'CountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/3',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 2,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 2,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/4',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 3,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 3,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/5',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 4,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 4,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/6',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 5,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 5,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/7',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 6,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 6,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/8',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 7,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 7,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/9',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 8,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 8,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/10',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 9,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 9,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/11',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 10,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 10,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/12',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 11,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 11,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/13',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 12,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 12,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/14',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 13,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 13,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/15',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 14,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 14,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/16',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 15,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 15,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/17',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 16,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 16,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/18',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 17,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 17,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/19',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 18,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 18,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/20',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 19,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 19,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/21',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 20,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 20,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/22',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 21,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 21,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/23',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 22,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 22,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/24',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 23,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 23,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/25',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 24,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 24,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/26',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 25,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 25,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/27',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 26,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 26,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/28',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 27,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 27,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/29',
#                                                                  'GraphType': 'table',
# ...
#                                                                  'GraphType': 'table',
#                                                                  'Id': 184,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 184,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/186',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 185,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 185,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/187',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 186,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 186,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/188',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 187,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 187,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/189',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 188,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 188,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/190',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 189,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 189,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/191',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 190,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 190,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/192',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 191,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 191,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Count '
#                                                                                 'of '
#                                                                                 'number '
#                                                                                 'of '
#                                                                                 'data '
#                                                                                 'in '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'case '
#                                                                                 'combinations',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/193',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 192,
#                                                                  'Name': 'CombinedCountResult',
#                                                                  'ReportIndex': 192,
#                                                                  'ReportName': 'CombinedCountResult',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'percentage '
#                                                                                 'of '
#                                                                                 'various '
#                                                                                 'high '
#                                                                                 'risk '
#                                                                                 'cases '
#                                                                                 'in '
#                                                                                 'data',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/194',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 193,
#                                                                  'Name': 'DistributionPlot',
#                                                                  'ReportIndex': 193,
#                                                                  'ReportName': 'DistributionPlot',
#                                                                  'ReportRequired': True}],
#                                                      'LogFile': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/196',
#                                                      'Summary': 'OK'},
#                            'TestRunner': {'Author': 'AIST',
#                                           'Description': 'Evaluating quantity '
#                                                          'of high risk CA '
#                                                          'combination cases in '
#                                                          'BDD dataset)',
#                                           'Email': '',
#                                           'Id': 4,
#                                           'LandingPage': '',
#                                           'Name': 'eval_find_ca_high_risk',
#                                           'Params': [],
#                                           'Quality': 'https://airc.aist.go.jp/aiqm/quality/internal/データセットの被覆性',
#                                           'Version': '0.1'}}}

# %%
# generate report
res = helper.post_report(td_1_json['Id'])
# Out:
# <Response [200]>
# {'OutParams': {'ReportUrl': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/197'},
#  'Result': {'Code': 'D12000', 'Message': 'command invoke success.'}}
