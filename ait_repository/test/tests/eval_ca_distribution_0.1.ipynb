# %% [markdown]
# # test note
#
#
# * jupyterはコンテナ起動すること
# * テストベッド一式起動済みであること

# %%
# !pip install --upgrade pip
# !pip install --force-reinstall ../lib/ait_sdk-0.1.5-py3-none-any.whl
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: pip in /opt/conda/lib/python3.8/site-packages (20.3.3)
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Processing /workdir/root/lib/ait_sdk-0.1.5-py3-none-any.whl
# Collecting keras<=2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting nbconvert<=6.0.7
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
#      |████████████████████████████████| 552 kB 7.6 MB/s eta 0:00:01
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting jinja2>=2.4
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 10.1 MB/s eta 0:00:01
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp38-cp38-manylinux1_x86_64.whl (32 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 10.8 MB/s ta 0:00:011
# Collecting jupyter-client>=6.1.5
#   Downloading jupyter_client-6.1.7-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 10.6 MB/s eta 0:00:01
# Collecting jupyter-core
#   Downloading jupyter_core-4.7.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 10.4 MB/s eta 0:00:01
# Collecting nbformat<=5.0.8
#   Downloading nbformat-5.0.8-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 11.5 MB/s eta 0:00:01
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 38.3 MB/s eta 0:00:01
# Collecting attrs>=17.4.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 12.8 MB/s eta 0:00:01
# Collecting numpy<=1.19.3
#   Downloading numpy-1.19.3-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 11.3 MB/s eta 0:00:01
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting psutil<=5.7.3
#   Downloading psutil-5.7.3.tar.gz (465 kB)
#      |████████████████████████████████| 465 kB 11.6 MB/s eta 0:00:01
# Collecting py-cpuinfo<=7.0.0
#   Downloading py-cpuinfo-7.0.0.tar.gz (95 kB)
#      |████████████████████████████████| 95 kB 14.8 MB/s eta 0:00:01
# Collecting pygments>=2.4.1
#   Downloading Pygments-2.7.3-py3-none-any.whl (950 kB)
#      |████████████████████████████████| 950 kB 11.7 MB/s eta 0:00:01
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
#      |████████████████████████████████| 106 kB 21.1 MB/s eta 0:00:01
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 10.5 MB/s eta 0:00:01
# Collecting pyzmq>=13
#   Downloading pyzmq-20.0.0-cp38-cp38-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.8 MB/s eta 0:00:01
# Collecting scipy>=0.14
#   Downloading scipy-1.5.4-cp38-cp38-manylinux1_x86_64.whl (25.8 MB)
#      |████████████████████████████████| 25.8 MB 21.8 MB/s eta 0:00:01   |████████▉                       | 7.1 MB 9.8 MB/s eta 0:00:02
# Collecting six>=1.11.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting tornado>=4.1
#   Downloading tornado-6.1-cp38-cp38-manylinux2010_x86_64.whl (427 kB)
#      |████████████████████████████████| 427 kB 10.8 MB/s eta 0:00:01
# Collecting traitlets>=4.2
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 11.0 MB/s ta 0:00:01
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting bleach
#   Downloading bleach-3.2.1-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 10.1 MB/s eta 0:00:01
# Collecting defusedxml
#   Downloading defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting h5py
#   Downloading h5py-3.1.0-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 10.1 MB/s eta 0:00:01
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.4.3-py3-none-any.whl (5.3 kB)
# Collecting packaging
#   Downloading packaging-20.8-py2.py3-none-any.whl (39 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 15.1 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 10.7 MB/s eta 0:00:01
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 11.8 MB/s eta 0:00:01
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting setuptools
#   Downloading setuptools-51.1.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 11.2 MB/s eta 0:00:01
# Building wheels for collected packages: pandocfilters, psutil, py-cpuinfo, pyrsistent, pyyaml
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7991 sha256=7dd5e12e7e357230b80b905bf0cdde34dd0a395df55a965a960334992f64babd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwgyxub_/wheels/fc/39/52/8d6f3cec1cca4ceb44d658427c35711b19d89dbc4914af657f
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.3-cp38-cp38-linux_x86_64.whl size=295127 sha256=aa30a5397f3601844bb0eb861145e266e3dca038147647807be93c65cae5cd4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwgyxub_/wheels/f6/59/c2/38111ef4c354088a156bc95fbeb5396c0cac91a0f62f7158b9
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-7.0.0-py3-none-any.whl size=20068 sha256=116eb52c428e15e249df72a3536f75e65afea4da6e183180f18e05ce62f213d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwgyxub_/wheels/b4/99/9f/8eb77fdf759c1380719071722f2c37dd0fa1f6aa477c51cb6c
#   Building wheel for pyrsistent (setup.py) ... done
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp38-cp38-linux_x86_64.whl size=132294 sha256=bbe331bdc5d4855a107f3f0c7ff10f881e1dfdf847daf47e70b7f36c0d45bc86
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwgyxub_/wheels/3d/22/08/7042eb6309c650c7b53615d5df5cc61f1ea9680e7edd3a08d2
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp38-cp38-linux_x86_64.whl size=44617 sha256=34820fa988181b6d63f2bac00a2887abd5e9877bab291cde219d5e27aaa1a631
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwgyxub_/wheels/13/90/db/290ab3a34f2ef0b5a0f89235dc2d40fea83e77de84ed2dc05c
# Successfully built pandocfilters psutil py-cpuinfo pyrsistent pyyaml
# Installing collected packages: ipython-genutils, traitlets, six, setuptools, pyrsistent, attrs, tornado, pyzmq, python-dateutil, pyparsing, jupyter-core, jsonschema, webencodings, pygments, packaging, numpy, nest-asyncio, nbformat, MarkupSafe, jupyter-client, async-generator, testpath, scipy, pyyaml, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, h5py, entrypoints, defusedxml, bleach, py-cpuinfo, psutil, nbconvert, keras, ait-sdk
#   Attempting uninstall: ipython-genutils
#     Found existing installation: ipython-genutils 0.2.0
#     Uninstalling ipython-genutils-0.2.0:
#       Successfully uninstalled ipython-genutils-0.2.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 51.0.0
#     Uninstalling setuptools-51.0.0:
#       Successfully uninstalled setuptools-51.0.0
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.17.3
#     Uninstalling pyrsistent-0.17.3:
#       Successfully uninstalled pyrsistent-0.17.3
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 20.0.0
#     Uninstalling pyzmq-20.0.0:
#       Successfully uninstalled pyzmq-20.0.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.7.0
#     Uninstalling jupyter-core-4.7.0:
#       Successfully uninstalled jupyter-core-4.7.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 3.2.0
#     Uninstalling jsonschema-3.2.0:
#       Successfully uninstalled jsonschema-3.2.0
#   Attempting uninstall: webencodings
#     Found existing installation: webencodings 0.5.1
#     Uninstalling webencodings-0.5.1:
#       Successfully uninstalled webencodings-0.5.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.7.2
#     Uninstalling Pygments-2.7.2:
#       Successfully uninstalled Pygments-2.7.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.4.3
#     Uninstalling nest-asyncio-1.4.3:
#       Successfully uninstalled nest-asyncio-1.4.3
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.8
#     Uninstalling nbformat-5.0.8:
#       Successfully uninstalled nbformat-5.0.8
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.7
#     Uninstalling jupyter-client-6.1.7:
#       Successfully uninstalled jupyter-client-6.1.7
#   Attempting uninstall: async-generator
#     Found existing installation: async-generator 1.10
#     Uninstalling async-generator-1.10:
#       Successfully uninstalled async-generator-1.10
#   Attempting uninstall: testpath
#     Found existing installation: testpath 0.4.4
#     Uninstalling testpath-0.4.4:
#       Successfully uninstalled testpath-0.4.4
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.4.2
#     Uninstalling pandocfilters-1.4.2:
#       Successfully uninstalled pandocfilters-1.4.2
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.5.1
#     Uninstalling nbclient-0.5.1:
#       Successfully uninstalled nbclient-0.5.1
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: jupyterlab-pygments
#     Found existing installation: jupyterlab-pygments 0.1.2
#     Uninstalling jupyterlab-pygments-0.1.2:
#       Successfully uninstalled jupyterlab-pygments-0.1.2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.3
#     Uninstalling entrypoints-0.3:
#       Successfully uninstalled entrypoints-0.3
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.6.0
#     Uninstalling defusedxml-0.6.0:
#       Successfully uninstalled defusedxml-0.6.0
#   Attempting uninstall: bleach
#     Found existing installation: bleach 3.2.1
#     Uninstalling bleach-3.2.1:
#       Successfully uninstalled bleach-3.2.1
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# Successfully installed MarkupSafe-1.1.1 ait-sdk-0.1.5 async-generator-1.10 attrs-20.3.0 bleach-3.2.1 defusedxml-0.6.0 entrypoints-0.3 h5py-3.1.0 ipython-genutils-0.2.0 jinja2-2.11.2 jsonschema-3.2.0 jupyter-client-6.1.7 jupyter-core-4.7.0 jupyterlab-pygments-0.1.2 keras-2.4.3 mistune-0.8.4 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 nest-asyncio-1.4.3 numpy-1.19.3 packaging-20.8 pandocfilters-1.4.3 psutil-5.7.3 py-cpuinfo-7.0.0 pygments-2.7.3 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 pyyaml-5.3.1 pyzmq-20.0.0 scipy-1.5.4 setuptools-51.1.0 six-1.15.0 testpath-0.4.4 tornado-6.1 traitlets-5.0.5 webencodings-0.5.1

# %%
from pathlib import Path
import pprint
from ait_sdk.test.hepler import Helper
import json

# %%
# settings cell

# mounted dir
root_dir = Path('/workdir/root/ait')

ait_name='eval_ca_distribution'
ait_version='0.1'

ait_full_name=f'{ait_name}_{ait_version}'
ait_dir = root_dir / ait_full_name

td_name=f'{ait_name}_test'

# (dockerホスト側の)インベントリ登録用アセット格納ルートフォルダ
current_dir = %pwd
with open(f'{current_dir}/config.json', encoding='utf-8') as f:
    json_ = json.load(f)
    root_dir = json_['host_ait_root_dir']
    is_container = json_['is_container']
invenotory_root_dir = f'{root_dir}\\ait\\{ait_full_name}\\local_qai\\inventory'

# entry point address
# コンテナ起動かどうかでポート番号が変わるため、切り替える
if is_container:
    backend_entry_point = 'http://host.docker.internal:8888/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:8888/qai-ip/api/0.0.1'
else:
    backend_entry_point = 'http://host.docker.internal:5000/qai-testbed/api/0.0.1'
    ip_entry_point = 'http://host.docker.internal:6000/qai-ip/api/0.0.1'

# aitのデプロイフラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_ait = True

# インベントリの登録フラグ
# 一度実施すれば、それ以降は実施しなくてＯＫ
is_init_inventory = True

# %%
helper = Helper(backend_entry_point=backend_entry_point, 
                ip_entry_point=ip_entry_point,
                ait_dir=ait_dir,
                ait_full_name=ait_full_name)

# %%
# health check

helper.get_bk('/health-check')
helper.get_ip('/health-check')
# Out:
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>
# {'Code': 0, 'Message': 'alive.'}
# <Response [200]>

# %%
# create ml-component
res = helper.post_ml_component(name=f'MLComponent_{ait_full_name}', description=f'Description of {ait_full_name}', problem_domain=f'ProbremDomain of {ait_full_name}')
helper.set_ml_component_id(res['MLComponentId'])
# Out:
# <Response [200]>
# {'MLComponentId': 6,
#  'Result': {'Code': 'P22000', 'Message': 'add ml-component success.'}}

# %%
# deploy AIT
if is_init_ait:
    helper.deploy_ait_non_build()
else:
    print('skip deploy AIT')
# Out:
# <Response [200]>
# {'Code': 'M00001', 'Message': 'Add AIT manifest success'}
# <Response [200]>
# {'Code': 'D00001', 'Message': 'Deploy success'}

# %%
res = helper.get_data_types()
model_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'model'][0]['Id']
dataset_data_type_id = [d for d in res['DataTypes'] if d['Name'] == 'dataset'][0]['Id']
res = helper.get_file_systems()
unix_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'UNIX_FILE_SYSTEM'][0]['Id']
windows_file_system_id = [f for f in res['FileSystems'] if f['Name'] == 'WINDOWS_FILE'][0]['Id']

# %%
# add inventories

if is_init_inventory:
    inv1_name = helper.post_inventory('Data', dataset_data_type_id, windows_file_system_id, 
                                      f'{invenotory_root_dir}\\BDD_data\\BDD_labels_2036.csv',
                                      'dataset', ['csv'])
else:
    print('skip add inventories')
# Out:
# <Response [200]>
# {'result': {'Code': 'I22000', 'Message': 'append Inventory success.'}}

# %%
# get ait_json and inventory_jsons

res_json = helper.get_bk('/QualityMeasurements/RelationalOperators', is_print_json=False).json()
eq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '=='][0])
nq_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '!='][0])
gt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>'][0])
ge_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '>='][0])
lt_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<'][0])
le_id = int([r['Id'] for r in res_json['RelationalOperator'] if r['Expression'] == '<='][0])

res_json = helper.get_bk('/testRunners', is_print_json=False).json()
ait_json = [j for j in res_json['TestRunners'] if j['Name'] == ait_name][-1]

inv_1_json = helper.get_inventory(inv1_name)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# add teast_descriptions

helper.post_td(td_name, ait_json['QualityDimensionId'],
               quality_measurements=[
               ],
               target_inventories=[
                {"Id":1, "InventoryId": inv_1_json['Id'], "TemplateInventoryId": ait_json['TargetInventories'][0]['Id']}
               ],
               test_runner={
                "Id":ait_json['Id'],
                "Params":[
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][0]['Id'], "Value":"7"},
                    {"TestRunnerParamTemplateId":ait_json['ParamTemplates'][1]['Id'], "Value":"1"},
                ]
               })
# Out:
# <Response [200]>
# {'Result': {'Code': 'T22000', 'Message': 'append test description success.'}}

# %%
# get test_description_jsons
td_1_json = helper.get_td(td_name)
# Out:
# <Response [200]>

# %%
# run test_descriptions
helper.post_run_and_wait(td_1_json['Id'])
# Out:
# <Response [200]>
# {'Job': {'Id': '3', 'StartDateTime': '2020-12-24 11:53:35.538850+09:00'},
#  'Result': {'Code': 'R12000', 'Message': 'job launch success.'}}
# [{'Id': 3,
#   'Result': 'OK',
#   'ResultDetail': 'No Measure',
#   'Status': 'DONE',
#   'TestDescriptionID': 6}]

# %%
res_json = helper.get_td_detail(td_1_json['Id'])
pprint.pprint(res_json)
# Out:
# <Response [200]>
# {'Result': {'Code': 'T32000', 'Message': 'get detail success.'},
#  'TestDescriptionDetail': {'Id': 6,
#                            'Name': 'eval_ca_distribution_test',
#                            'Opinion': '',
#                            'QualityDimension': {'Id': 1,
#                                                 'Name': 'Completeness_of_problem_domain_analysis'},
#                            'QualityMeasurements': [],
#                            'Star': False,
#                            'TargetInventories': [{'DataType': {'Id': 1,
#                                                                'Name': 'dataset'},
#                                                   'Description': 'dataset',
#                                                   'Id': 16,
#                                                   'Name': 'eval_ca_distribution_0.1_Data',
#                                                   'TemplateInventoryId': 16}],
#                            'TestDescriptionResult': {'Detail': 'No Measure',
#                                                      'Downloads': [{'Description': 'AITLog',
#                                                                     'DownloadURL': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/41',
#                                                                     'FileName': 'ait.log',
#                                                                     'Id': 18,
#                                                                     'Name': 'Log'}],
#                                                      'Graphs': [{'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Roadtype.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/27',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 5,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 1,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Roadtype.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/28',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 6,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 2,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Weather.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/29',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 7,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 3,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Weather.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/30',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 8,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 4,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Lighting.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/31',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 9,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 5,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Lighting.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/32',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 10,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 6,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Obstacle.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/33',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 11,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 7,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Obstacle.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/34',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 12,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 8,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Pedestrian.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/35',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 13,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 9,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Pedestrian.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/36',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 14,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 10,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Signal.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/37',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 15,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 11,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Signal.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/38',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 16,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 12,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Table '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Roadcondition.csv',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/39',
#                                                                  'GraphType': 'table',
#                                                                  'Id': 17,
#                                                                  'Name': 'distibution_csv',
#                                                                  'ReportIndex': 13,
#                                                                  'ReportName': 'distibution_csv',
#                                                                  'ReportRequired': True},
#                                                                 {'Description': 'Plot '
#                                                                                 'of '
#                                                                                 'distribution '
#                                                                                 'for '
#                                                                                 'each '
#                                                                                 'combination',
#                                                                  'FileName': 'Roadcondition.jpg',
#                                                                  'Graph': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/40',
#                                                                  'GraphType': 'picture',
#                                                                  'Id': 18,
#                                                                  'Name': 'distibution_plot',
#                                                                  'ReportIndex': 14,
#                                                                  'ReportName': 'distibution_plot',
#                                                                  'ReportRequired': True}],
#                                                      'LogFile': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/42',
#                                                      'Summary': 'OK'},
#                            'TestRunner': {'Author': 'AIST',
#                                           'Description': 'Evaluating '
#                                                          'distribution of '
#                                                          'dataset with '
#                                                          'expected '
#                                                          'distribution',
#                                           'Email': '',
#                                           'Id': 6,
#                                           'LandingPage': '',
#                                           'Name': 'eval_ca_distribution',
#                                           'Params': [{'Id': 17,
#                                                       'Name': 'attribute_no',
#                                                       'TestRunnerParamTemplateId': 17,
#                                                       'Value': '7'},
#                                                      {'Id': 18,
#                                                       'Name': 'dimension',
#                                                       'TestRunnerParamTemplateId': 18,
#                                                       'Value': '1'}],
#                                           'Quality': 'https://airc.aist.go.jp/aiqm/quality/internal/Distribution_of_training_data',
#                                           'Version': '0.1'}}}

# %%
# generate report
res = helper.post_report(td_1_json['Id'])
# Out:
# <Response [200]>
# {'OutParams': {'ReportUrl': 'http://127.0.0.1:5000/qai-testbed/api/0.0.1/download/43'},
#  'Result': {'Code': 'D12000', 'Message': 'command invoke success.'}}
